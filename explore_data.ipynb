# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

# %%
df_pollution = pd.read_csv('data/global air pollution dataset.csv')
df_pollution
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
pd.plotting.scatter_matrix(df_pollution, alpha=0.2, figsize=(10, 10))
# Out:
# array([[<Axes: xlabel='AQI Value', ylabel='AQI Value'>,
#         <Axes: xlabel='CO AQI Value', ylabel='AQI Value'>,
#         <Axes: xlabel='Ozone AQI Value', ylabel='AQI Value'>,
#         <Axes: xlabel='NO2 AQI Value', ylabel='AQI Value'>,
#         <Axes: xlabel='PM2.5 AQI Value', ylabel='AQI Value'>],
#        [<Axes: xlabel='AQI Value', ylabel='CO AQI Value'>,
#         <Axes: xlabel='CO AQI Value', ylabel='CO AQI Value'>,
#         <Axes: xlabel='Ozone AQI Value', ylabel='CO AQI Value'>,
#         <Axes: xlabel='NO2 AQI Value', ylabel='CO AQI Value'>,
#         <Axes: xlabel='PM2.5 AQI Value', ylabel='CO AQI Value'>],
#        [<Axes: xlabel='AQI Value', ylabel='Ozone AQI Value'>,
#         <Axes: xlabel='CO AQI Value', ylabel='Ozone AQI Value'>,
#         <Axes: xlabel='Ozone AQI Value', ylabel='Ozone AQI Value'>,
#         <Axes: xlabel='NO2 AQI Value', ylabel='Ozone AQI Value'>,
#         <Axes: xlabel='PM2.5 AQI Value', ylabel='Ozone AQI Value'>],
# ...

# %%
df_air_quality = pd.read_csv('data/AirQuality.csv', sep=';')

# %%
df_air_quality.plot(x='Date', y=['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH'], kind='line', figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %%
df_week = df_air_quality.head(100)
df_week.plot(x='Date', y=['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH'], kind='line', figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>
